# %%
import sys
sys.stdin = open("input.txt", "rt")
input = sys.stdin.readline

# 크기가 n x n
# 치킨 거리는 집과 가장 가까운 치킨집 사이의 거리 모든 치킨 거리의 합
# 1은 집, 2는 치킨집

# 치킨 거리가 가장 작게 되는 최대 M개를 고르기
n, m = map(int, input().split())
board = [list(map(int, input().split())) for _ in range(n)]
global answer
answer = 1e9

def dfs(L, chicken_start):

    # m개의 치킨집을 골랐다면
    if L == m:
        global answer
        answer_tmp = 0
        # 집에서 가장 작은 거리를 구하기
        for i in range(home_len):
            min_len = 1e9
            for j in range(chicken_len):
                if chicken_visited[j]:
                    r1, c1 = home[i]
                    r2, c2 = chicken[j]
                    min_len = min(min_len, abs(r1 - r2) + abs(c1 - c2))
            
            answer_tmp += min_len
            
        answer = min(answer, answer_tmp)


    for i in range(chicken_start, chicken_len):
        if not chicken_visited[i]:
            chicken_visited[i] = True
            dfs(L + 1, i + 1)
            chicken_visited[i] = False

home = [];chicken = []
# 1, 2 찾기
for i in range(n):
    for j in range(n):
        if board[i][j] == 1:
            home.append([i, j])
        elif board[i][j] == 2:
            chicken.append([i, j])

home_len = len(home)
chicken_len = len(chicken)

chicken_visited = [False] * (chicken_len)
dfs(0, 0)
print(answer)

# %%
import sys
sys.stdin = open("input.txt", "rt")
input = sys.stdin.readline

# 크기가 n x n
# 치킨 거리는 집과 가장 가까운 치킨집 사이의 거리 모든 치킨 거리의 합
# 1은 집, 2는 치킨집

# 치킨 거리가 가장 작게 되는 최대 M개를 고르기
n, m = map(int, input().split())
board = [list(map(int, input().split())) for _ in range(n)]
global answer
answer = 1e9

chicken_visited = []
def dfs(L, chicken_start):

    # m개의 치킨집을 골랐다면
    if L == m:
        global answer
        answer_tmp = 0
        # 집에서 가장 작은 거리를 구하기
        for i in range(home_len):
            min_len = 1e9
            for j in range(len(chicken_visited)):
                r1, c1 = home[i]
                r2, c2 = chicken[chicken_visited[j]]
                min_len = min(min_len, abs(r1 - r2) + abs(c1 - c2))
            
            answer_tmp += min_len
            
        answer = min(answer, answer_tmp)

    for i in range(chicken_start, chicken_len):
        chicken_visited.append(i)
        dfs(L + 1, i + 1)
        chicken_visited.pop()

home = [];chicken = []
# 1, 2 찾기
for i in range(n):
    for j in range(n):
        if board[i][j] == 1:
            home.append([i, j])
        elif board[i][j] == 2:
            chicken.append([i, j])

home_len = len(home)
chicken_len = len(chicken)

dfs(0, 0)
print(answer)
